# %%
# %pip install -U sagemaker
# %pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.128.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (1.5.1)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (1.22.4)
# Requirement already satisfied: boto3<2.0,>=1.26.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (1.26.44)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (0.3.0)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (3.20.3)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (4.13.0)
# Requirement already satisfied: attrs<23,>=20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (22.1.0)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker) (0.7.5)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.26.28->sagemaker) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.26.28->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.44 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.26.28->sagemaker) (1.29.50)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->sagemaker) (3.0.9)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from protobuf3-to-dict<1.0,>=0.1.5->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker) (2022.5)
# Requirement already satisfied: pox>=0.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.2)
# Requirement already satisfied: dill>=0.3.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.6)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker) (1.7.6.6)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker) (0.70.14)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from schema->sagemaker) (21.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.44->boto3<2.0,>=1.26.28->sagemaker) (1.26.8)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: xgboost in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.7.3)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from xgboost) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:sagemaker.image_uris:Defaulting to only available Python version: py3

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import SKLearnProcessor

region = boto3.session.Session().region_name

role = get_execution_role()
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:sagemaker.image_uris:Defaulting to only available Python version: py3

# %%
import pandas as pd
data = "s3://finkers-bucket/alldata/cleaned_startups.csv".format(region)
df = pd.read_csv(data)

list(df)
# Out:
# ['Unnamed: 0',
#  'id',
#  'created_at',
#  'funding_rounds',
#  'funding_total_usd',
#  'number_of_members',
#  'number_of_founders',
#  'pre_money_valuation',
#  'post_money_valuation',
#  'mean_funding',
#  'max_funding',
#  'crowdfunding',
#  'post-ipo',
#  'private-equity',
#  'venture',
#  'a',
#  'angel',
#  'b',
#  'c',
#  'convertible',
#  'crowd',
#  'crowd_equity',
#  'd',
#  'debt_round',
#  'e',
#  'f',
#  'g',
#  'grant',
#  'partial',
#  'post_ipo_debt',
#  'post_ipo_equity',
#  'private_equity',
#  'secondary_market',
#  'seed',
#  'unattributed',
#  'number of invested VCs',
#  'total investment from VCs']

# %%
# Data cleaning

# Check that there is no missing data
CATEGORICAL = list(filter(lambda x: df[x].dtype=='object',df.columns))
def show_stats(columns):
    stat = {}
    for col in columns:
        stat[col] =  [df[col].nunique(), df[col].isna().mean()*100, df[col].dtype]
    return pd.DataFrame.from_dict(stat, orient='index', columns=['Unique',  'Missed values in %', 'DType'])
show_stats(CATEGORICAL)
# Out:
#             Unique  Missed values in %   DType
# id           26709                 0.0  object
# created_at   26580                 0.0  object

# %%
import numpy as np

valid = df.loc[df['post_money_valuation'] > 0]
valid = valid.drop("pre_money_valuation", axis=1).drop("id",axis=1)
valid["created_at"] = pd.to_datetime(valid["created_at"])
valid['year'] = pd.DatetimeIndex(valid['created_at']).year
valid['month'] = pd.DatetimeIndex(valid['created_at']).month
valid['day'] = pd.DatetimeIndex(valid['created_at']).day
valid = valid.drop("created_at",axis=1)


# Remove data that have pre but not post valuation (consider removing)
remove = df.loc[(df['post_money_valuation'] == 0) & (df['pre_money_valuation'] > 0)]

valid.dtypes
# Out:
# Unnamed: 0                     int64
# funding_rounds                 int64
# funding_total_usd            float64
# number_of_members            float64
# number_of_founders           float64
# post_money_valuation         float64
# mean_funding                 float64
# max_funding                  float64
# crowdfunding                 float64
# post-ipo                     float64
# private-equity               float64
# venture                      float64
# a                            float64
# angel                        float64
# b                            float64
# c                            float64
# convertible                  float64
# crowd                        float64
# crowd_equity                 float64
# d                            float64
# debt_round                   float64
# e                            float64
# f                            float64
# g                            float64
# grant                        float64
# partial                      float64
# post_ipo_debt                float64
# post_ipo_equity              float64
# private_equity               float64
# secondary_market             float64
# seed                         float64
# unattributed                 float64
# number of invested VCs       float64
# total investment from VCs    float64
# year                           int64
# month                          int64
# day                            int64
# dtype: object

# %%
# Allocate training and test sets, and save files to bucket
import sagemaker,boto3, os

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    valid.drop("post_money_valuation", axis=1),
    valid["post_money_valuation"],
    test_size = 0.2,
    random_state = 0)

#Log10 transform target col
y_train = np.log10(y_train)
y_test = np.log10(y_test)

final_train = X_train.copy()
final_train.insert(0,"post_money_valuation",y_train)

final_test = X_test.copy()
final_test.insert(0,"post_money_valuation",y_test)

final_train.to_csv("final_training.csv", index=False, header=False)
final_test.to_csv("final_testing.csv", index=False, header=False)

bucket = 'finkers-bucket'

boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join('training/final_training.csv')).upload_file('final_training.csv')

boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join('validation/final_testing.csv')).upload_file('final_testing.csv')
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.session import Session
from sagemaker.inputs import TrainingInput

hyperparameters = {
        "max_depth":"5",
        "eta":"0.2",
        "gamma":"3",
        "min_child_weight":"6",
        "subsample":"0.7",
        "verbosity":"1",
        "objective":"reg:squarederror",
        "num_round":"1000",
        "early_stopping_rounds": "5"}

output_path = 's3://finkers-bucket/output/'

xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.5-1", "latest")
estimator = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=role,
                                          instance_count=1, 
                                          instance_type='ml.m4.xlarge', 
                                          volume_size=1, # 1 GB 
                                          output_path=output_path)

# define the data type and paths to the training and validation datasets
content_type = "csv"
train_input = TrainingInput("s3://{}/{}/{}".format(bucket, 'training', "final_training.csv"), content_type=content_type)
validation_input = TrainingInput("s3://{}/{}/{}".format(bucket, 'validation', 'final_testing.csv'), content_type=content_type)

# execute the XGBoost training job
estimator.fit({'train': train_input, "validation": validation_input})
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary Python version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-01-16-08-55-05-141
# 2023-01-16 08:55:05 Starting - Starting the training job...
# 2023-01-16 08:55:21 Starting - Preparing the instances for training......
# 2023-01-16 08:56:31 Downloading - Downloading input data...
# 2023-01-16 08:57:01 Training - Downloading the training image......
# 2023-01-16 08:57:37 Training - Training image download completed. Training in progress.[2023-01-16 08:57:53.804 ip-10-0-169-108.ap-southeast-1.compute.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-01-16:08:57:53:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-01-16:08:57:53:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-01-16:08:57:53:INFO] No GPUs detected (normal if no gpus installed)
# [2023-01-16:08:57:53:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-01-16:08:57:53:INFO] Determined delimiter of CSV input is ','
# [2023-01-16:08:57:53:INFO] Determined delimiter of CSV input is ','
# [2023-01-16:08:57:53:INFO] files path: /opt/ml/input/data/train
# [2023-01-16:08:57:53:INFO] Determined delimiter of CSV input is ','
# [2023-01-16:08:57:53:INFO] files path: /opt/ml/input/data/validation
# [2023-01-16:08:57:53:INFO] Determined delimiter of CSV input is ','
# [2023-01-16:08:57:53:INFO] Single node training.
# [2023-01-16:08:57:53:INFO] Train matrix has 775 rows and 36 columns
# [2023-01-16:08:57:53:INFO] Validation matrix has 194 rows
# [2023-01-16 08:57:53.903 ip-10-0-169-108.ap-southeast-1.compute.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [0]#011train-rmse:4.73861#011validation-rmse:4.74111
# [1]#011train-rmse:3.84407#011validation-rmse:3.83466
# [2]#011train-rmse:3.15294#011validation-rmse:3.12619
# [3]#011train-rmse:2.60251#011validation-rmse:2.55285
# [4]#011train-rmse:2.16974#011validation-rmse:2.09899
# [5]#011train-rmse:1.84519#011validation-rmse:1.74579
# [6]#011train-rmse:1.59806#011validation-rmse:1.47469
# [7]#011train-rmse:1.40971#011validation-rmse:1.25970
# [8]#011train-rmse:1.28283#011validation-rmse:1.10839
# [9]#011train-rmse:1.18395#011validation-rmse:0.98663
# [10]#011train-rmse:1.11258#011validation-rmse:0.89935
# [11]#011train-rmse:1.06223#011validation-rmse:0.83115
# [12]#011train-rmse:1.02957#011validation-rmse:0.78421
# [13]#011train-rmse:1.00947#011validation-rmse:0.73717
# [14]#011train-rmse:0.98331#011validation-rmse:0.70478
# [15]#011train-rmse:0.97204#011validation-rmse:0.69061
# [16]#011train-rmse:0.96149#011validation-rmse:0.68063
# [17]#011train-rmse:0.95308#011validation-rmse:0.66924
# [18]#011train-rmse:0.94826#011validation-rmse:0.66128
# [19]#011train-rmse:0.94342#011validation-rmse:0.64337
# [20]#011train-rmse:0.93810#011validation-rmse:0.63296
# [21]#011train-rmse:0.91732#011validation-rmse:0.64057
# [22]#011train-rmse:0.90321#011validation-rmse:0.64096
# [23]#011train-rmse:0.89426#011validation-rmse:0.64030
# [24]#011train-rmse:0.89188#011validation-rmse:0.64290
# [25]#011train-rmse:0.89074#011validation-rmse:0.63214
# [26]#011train-rmse:0.88789#011validation-rmse:0.63128
# [27]#011train-rmse:0.88365#011validation-rmse:0.63784
# [28]#011train-rmse:0.87869#011validation-rmse:0.64563
# [29]#011train-rmse:0.87294#011validation-rmse:0.65131
# [30]#011train-rmse:0.86726#011validation-rmse:0.65216
# [31]#011train-rmse:0.86363#011validation-rmse:0.65603
# [32]#011train-rmse:0.85432#011validation-rmse:0.66665
# [33]#011train-rmse:0.85176#011validation-rmse:0.66671
# [34]#011train-rmse:0.84387#011validation-rmse:0.67052
# [345]#011train-rmse:0.56838#011validation-rmse:0.80499
# [346]#011train-rmse:0.56839#011validation-rmse:0.80503
# [347]#011train-rmse:0.56834#011validation-rmse:0.80451
# [348]#011train-rmse:0.56828#011validation-rmse:0.80373
# [349]#011train-rmse:0.56825#011validation-rmse:0.80299
# [350]#011train-rmse:0.56825#011validation-rmse:0.80300
# [351]#011train-rmse:0.56824#011validation-rmse:0.80263
# [352]#011train-rmse:0.56825#011validation-rmse:0.80305
# [353]#011train-rmse:0.56824#011validation-rmse:0.80205
# [354]#011train-rmse:0.56827#011validation-rmse:0.80133
# [355]#011train-rmse:0.56824#011validation-rmse:0.80238
# [356]#011train-rmse:0.56824#011validation-rmse:0.80251
# [357]#011train-rmse:0.56824#011validation-rmse:0.80259
# [358]#011train-rmse:0.56824#011validation-rmse:0.80217
# [359]#011train-rmse:0.56824#011validation-rmse:0.80250
# [360]#011train-rmse:0.56824#011validation-rmse:0.80254
# [361]#011train-rmse:0.56826#011validation-rmse:0.80331
# [362]#011train-rmse:0.56830#011validation-rmse:0.80405
# [363]#011train-rmse:0.56826#011validation-rmse:0.80330
# [364]#011train-rmse:0.56824#011validation-rmse:0.80261
# [365]#011train-rmse:0.56824#011validation-rmse:0.80224
# [366]#011train-rmse:0.56824#011validation-rmse:0.80268
# [367]#011train-rmse:0.56824#011validation-rmse:0.80206
# [368]#011train-rmse:0.56824#011validation-rmse:0.80237
# [369]#011train-rmse:0.56825#011validation-rmse:0.80168
# [370]#011train-rmse:0.56832#011validation-rmse:0.80055
# [371]#011train-rmse:0.56830#011validation-rmse:0.80086
# [372]#011train-rmse:0.56829#011validation-rmse:0.80089
# [373]#011train-rmse:0.56826#011validation-rmse:0.80136
# [374]#011train-rmse:0.56825#011validation-rmse:0.80177
# [375]#011train-rmse:0.56827#011validation-rmse:0.80121
# [376]#011train-rmse:0.56828#011validation-rmse:0.80114
# [377]#011train-rmse:0.56824#011validation-rmse:0.80246
# [378]#011train-rmse:0.56824#011validation-rmse:0.80256
# [379]#011train-rmse:0.56825#011validation-rmse:0.80306
# [380]#011train-rmse:0.56824#011validation-rmse:0.80244
# [381]#011train-rmse:0.56826#011validation-rmse:0.80142
# [382]#011train-rmse:0.56826#011validation-rmse:0.80153
# [383]#011train-rmse:0.56825#011validation-rmse:0.80165
# [384]#011train-rmse:0.56824#011validation-rmse:0.80193
# [385]#011train-rmse:0.56824#011validation-rmse:0.80276
# [386]#011train-rmse:0.56824#011validation-rmse:0.80288
# [387]#011train-rmse:0.56824#011validation-rmse:0.80287
# [388]#011train-rmse:0.56825#011validation-rmse:0.80180
# [389]#011train-rmse:0.56825#011validation-rmse:0.80301
# [390]#011train-rmse:0.56824#011validation-rmse:0.80247
# [391]#011train-rmse:0.56825#011validation-rmse:0.80300
# [392]#011train-rmse:0.56824#011validation-rmse:0.80269
# [393]#011train-rmse:0.56825#011validation-rmse:0.80329
# [394]#011train-rmse:0.56825#011validation-rmse:0.80324
# [395]#011train-rmse:0.56828#011validation-rmse:0.80376
# [396]#011train-rmse:0.56830#011validation-rmse:0.80409
# [552]#011train-rmse:0.55806#011validation-rmse:0.80138
# [553]#011train-rmse:0.55803#011validation-rmse:0.80071
# [554]#011train-rmse:0.55804#011validation-rmse:0.80100
# [555]#011train-rmse:0.55802#011validation-rmse:0.80015
# [556]#011train-rmse:0.55802#011validation-rmse:0.79998
# [557]#011train-rmse:0.55804#011validation-rmse:0.79923
# [558]#011train-rmse:0.55803#011validation-rmse:0.79951
# [559]#011train-rmse:0.55802#011validation-rmse:0.80021
# [560]#011train-rmse:0.55802#011validation-rmse:0.80002
# [561]#011train-rmse:0.55802#011validation-rmse:0.80007
# [562]#011train-rmse:0.55803#011validation-rmse:0.80043
# [563]#011train-rmse:0.55802#011validation-rmse:0.80021
# [564]#011train-rmse:0.55803#011validation-rmse:0.79947
# [565]#011train-rmse:0.55802#011validation-rmse:0.80014
# [566]#011train-rmse:0.55803#011validation-rmse:0.80067
# [567]#011train-rmse:0.55804#011validation-rmse:0.80105
# [568]#011train-rmse:0.55804#011validation-rmse:0.80087
# [569]#011train-rmse:0.55805#011validation-rmse:0.80109
# [570]#011train-rmse:0.55802#011validation-rmse:0.80039
# [571]#011train-rmse:0.55802#011validation-rmse:0.80021
# [572]#011train-rmse:0.55802#011validation-rmse:0.79990
# [573]#011train-rmse:0.55805#011validation-rmse:0.79903
# [574]#011train-rmse:0.55804#011validation-rmse:0.79934
# [575]#011train-rmse:0.55803#011validation-rmse:0.79966
# [576]#011train-rmse:0.55804#011validation-rmse:0.79928
# [577]#011train-rmse:0.55804#011validation-rmse:0.79925
# [578]#011train-rmse:0.55805#011validation-rmse:0.79912
# [579]#011train-rmse:0.55803#011validation-rmse:0.79956
# [580]#011train-rmse:0.55706#011validation-rmse:0.80089
# [581]#011train-rmse:0.55639#011validation-rmse:0.80409
# [582]#011train-rmse:0.55638#011validation-rmse:0.80330
# [583]#011train-rmse:0.55638#011validation-rmse:0.80348
# [584]#011train-rmse:0.55638#011validation-rmse:0.80353
# [585]#011train-rmse:0.55638#011validation-rmse:0.80311
# [586]#011train-rmse:0.55639#011validation-rmse:0.80258
# [587]#011train-rmse:0.55644#011validation-rmse:0.80166
# [588]#011train-rmse:0.55639#011validation-rmse:0.80253
# [589]#011train-rmse:0.55640#011validation-rmse:0.80235
# [590]#011train-rmse:0.55638#011validation-rmse:0.80322
# [591]#011train-rmse:0.55641#011validation-rmse:0.80454
# [592]#011train-rmse:0.55638#011validation-rmse:0.80378
# [593]#011train-rmse:0.55638#011validation-rmse:0.80346
# [594]#011train-rmse:0.55639#011validation-rmse:0.80264
# [595]#011train-rmse:0.55641#011validation-rmse:0.80215
# [596]#011train-rmse:0.55643#011validation-rmse:0.80178
# [597]#011train-rmse:0.55638#011validation-rmse:0.80278
# [598]#011train-rmse:0.55638#011validation-rmse:0.80298
# [599]#011train-rmse:0.55638#011validation-rmse:0.80331
# [600]#011train-rmse:0.55638#011validation-rmse:0.80326
# [601]#011train-rmse:0.55638#011validation-rmse:0.80354
# [602]#011train-rmse:0.55638#011validation-rmse:0.80378
# [603]#011train-rmse:0.55638#011validation-rmse:0.80380
# [604]#011train-rmse:0.55641#011validation-rmse:0.80447
# [605]#011train-rmse:0.55497#011validation-rmse:0.80334
# [606]#011train-rmse:0.55496#011validation-rmse:0.80303
# [607]#011train-rmse:0.55495#011validation-rmse:0.80233
# [608]#011train-rmse:0.55496#011validation-rmse:0.80192
# [609]#011train-rmse:0.55496#011validation-rmse:0.80215
# [610]#011train-rmse:0.55496#011validation-rmse:0.80225
# [611]#011train-rmse:0.55285#011validation-rmse:0.80622
# [612]#011train-rmse:0.55285#011validation-rmse:0.80616
# [613]#011train-rmse:0.55285#011validation-rmse:0.80603
# [614]#011train-rmse:0.55285#011validation-rmse:0.80607
# [615]#011train-rmse:0.55284#011validation-rmse:0.80624
# [616]#011train-rmse:0.55288#011validation-rmse:0.80556
# [617]#011train-rmse:0.55289#011validation-rmse:0.80542
# [618]#011train-rmse:0.55285#011validation-rmse:0.80602
# [619]#011train-rmse:0.55284#011validation-rmse:0.80645
# [620]#011train-rmse:0.55290#011validation-rmse:0.80532
# [621]#011train-rmse:0.55288#011validation-rmse:0.80560
# [622]#011train-rmse:0.55289#011validation-rmse:0.80534
# [623]#011train-rmse:0.55288#011validation-rmse:0.80546
# [624]#011train-rmse:0.55290#011validation-rmse:0.80522
# [625]#011train-rmse:0.55285#011validation-rmse:0.80615
# [626]#011train-rmse:0.55284#011validation-rmse:0.80646
# [627]#011train-rmse:0.55285#011validation-rmse:0.80601
# [628]#011train-rmse:0.55283#011validation-rmse:0.80685
# [629]#011train-rmse:0.55284#011validation-rmse:0.80747
# [630]#011train-rmse:0.55286#011validation-rmse:0.80790
# [631]#011train-rmse:0.55291#011validation-rmse:0.80859
# [632]#011train-rmse:0.55284#011validation-rmse:0.80736
# [633]#011train-rmse:0.55284#011validation-rmse:0.80652
# [634]#011train-rmse:0.55284#011validation-rmse:0.80634
# [635]#011train-rmse:0.55225#011validation-rmse:0.80859
# [636]#011train-rmse:0.55224#011validation-rmse:0.80817
# [637]#011train-rmse:0.55224#011validation-rmse:0.80821
# [638]#011train-rmse:0.55225#011validation-rmse:0.80734
# [639]#011train-rmse:0.55224#011validation-rmse:0.80760
# [640]#011train-rmse:0.55224#011validation-rmse:0.80768
# [641]#011train-rmse:0.55224#011validation-rmse:0.80816
# [642]#011train-rmse:0.55224#011validation-rmse:0.80771
# [643]#011train-rmse:0.54845#011validation-rmse:0.80698
# [644]#011train-rmse:0.54845#011validation-rmse:0.80695
# [645]#011train-rmse:0.54845#011validation-rmse:0.80793
# [646]#011train-rmse:0.54844#011validation-rmse:0.80769
# [647]#011train-rmse:0.54844#011validation-rmse:0.80783
# [648]#011train-rmse:0.54844#011validation-rmse:0.80724
# [649]#011train-rmse:0.54846#011validation-rmse:0.80673
# [650]#011train-rmse:0.54848#011validation-rmse:0.80638
# [651]#011train-rmse:0.54846#011validation-rmse:0.80684
# [652]#011train-rmse:0.54844#011validation-rmse:0.80721
# [653]#011train-rmse:0.54844#011validation-rmse:0.80787
# [654]#011train-rmse:0.54846#011validation-rmse:0.80844
# [655]#011train-rmse:0.54847#011validation-rmse:0.80870
# [656]#011train-rmse:0.54845#011validation-rmse:0.80825
# [657]#011train-rmse:0.54845#011validation-rmse:0.80793
# [658]#011train-rmse:0.54847#011validation-rmse:0.80856
# [659]#011train-rmse:0.54848#011validation-rmse:0.80888
# [660]#011train-rmse:0.54851#011validation-rmse:0.80923
# [661]#011train-rmse:0.54853#011validation-rmse:0.80947
# [662]#011train-rmse:0.54846#011validation-rmse:0.80852
# [663]#011train-rmse:0.54847#011validation-rmse:0.80856
# [664]#011train-rmse:0.54610#011validation-rmse:0.81171
# [665]#011train-rmse:0.54610#011validation-rmse:0.81171
# [666]#011train-rmse:0.54608#011validation-rmse:0.81103
# [667]#011train-rmse:0.54608#011validation-rmse:0.81122
# [668]#011train-rmse:0.54608#011validation-rmse:0.81130
# [669]#011train-rmse:0.54609#011validation-rmse:0.81158
# [670]#011train-rmse:0.54609#011validation-rmse:0.81157
# [671]#011train-rmse:0.54607#011validation-rmse:0.81053
# [672]#011train-rmse:0.54607#011validation-rmse:0.81060
# [673]#011train-rmse:0.54607#011validation-rmse:0.81091
# [674]#011train-rmse:0.54610#011validation-rmse:0.81169
# [675]#011train-rmse:0.54609#011validation-rmse:0.81149
# [676]#011train-rmse:0.54608#011validation-rmse:0.81115
# [677]#011train-rmse:0.54608#011validation-rmse:0.81119
# [678]#011train-rmse:0.54608#011validation-rmse:0.81110
# [679]#011train-rmse:0.54609#011validation-rmse:0.81154
# [680]#011train-rmse:0.54608#011validation-rmse:0.81118
# [681]#011train-rmse:0.54608#011validation-rmse:0.81111
# [682]#011train-rmse:0.54610#011validation-rmse:0.81185
# [683]#011train-rmse:0.54611#011validation-rmse:0.81188
# [684]#011train-rmse:0.54460#011validation-rmse:0.81331
# [685]#011train-rmse:0.54460#011validation-rmse:0.81318
# [686]#011train-rmse:0.54459#011validation-rmse:0.81268
# [687]#011train-rmse:0.54461#011validation-rmse:0.81340
# [688]#011train-rmse:0.54459#011validation-rmse:0.81300
# [689]#011train-rmse:0.54459#011validation-rmse:0.81265
# [690]#011train-rmse:0.54459#011validation-rmse:0.81281
# [691]#011train-rmse:0.54459#011validation-rmse:0.81280
# [692]#011train-rmse:0.54459#011validation-rmse:0.81281
# [693]#011train-rmse:0.54458#011validation-rmse:0.81250
# [694]#011train-rmse:0.54463#011validation-rmse:0.81118
# [695]#011train-rmse:0.54461#011validation-rmse:0.81151
# [696]#011train-rmse:0.54461#011validation-rmse:0.81154
# [697]#011train-rmse:0.54459#011validation-rmse:0.81192
# [698]#011train-rmse:0.54459#011validation-rmse:0.81189
# [699]#011train-rmse:0.54459#011validation-rmse:0.81199
# [700]#011train-rmse:0.54459#011validation-rmse:0.81285
# [701]#011train-rmse:0.54458#011validation-rmse:0.81244
# [702]#011train-rmse:0.54459#011validation-rmse:0.81285
# [703]#011train-rmse:0.54464#011validation-rmse:0.81400
# [704]#011train-rmse:0.54460#011validation-rmse:0.81324
# [705]#011train-rmse:0.54460#011validation-rmse:0.81322
# [706]#011train-rmse:0.54459#011validation-rmse:0.81276
# [707]#011train-rmse:0.54458#011validation-rmse:0.81263
# [708]#011train-rmse:0.54460#011validation-rmse:0.81319
# [709]#011train-rmse:0.54462#011validation-rmse:0.81367
# [710]#011train-rmse:0.54461#011validation-rmse:0.81337
# [711]#011train-rmse:0.54462#011validation-rmse:0.81361
# [712]#011train-rmse:0.54464#011validation-rmse:0.81400
# [713]#011train-rmse:0.54463#011validation-rmse:0.81389
# [714]#011train-rmse:0.54436#011validation-rmse:0.81283
# [715]#011train-rmse:0.54437#011validation-rmse:0.81245
# [716]#011train-rmse:0.54439#011validation-rmse:0.81196
# [717]#011train-rmse:0.54439#011validation-rmse:0.81186
# [718]#011train-rmse:0.54443#011validation-rmse:0.81133
# [719]#011train-rmse:0.54445#011validation-rmse:0.81115
# [720]#011train-rmse:0.54440#011validation-rmse:0.81178
# [721]#011train-rmse:0.54438#011validation-rmse:0.81215
# [722]#011train-rmse:0.54436#011validation-rmse:0.81269
# [723]#011train-rmse:0.54280#011validation-rmse:0.81282
# [724]#011train-rmse:0.54280#011validation-rmse:0.81287
# [725]#011train-rmse:0.54288#011validation-rmse:0.81170
# [726]#011train-rmse:0.54285#011validation-rmse:0.81194
# [727]#011train-rmse:0.54288#011validation-rmse:0.81161
# [728]#011train-rmse:0.54293#011validation-rmse:0.81122
# [729]#011train-rmse:0.54287#011validation-rmse:0.81179
# [730]#011train-rmse:0.54285#011validation-rmse:0.81205
# [731]#011train-rmse:0.54113#011validation-rmse:0.81333
# [732]#011train-rmse:0.54112#011validation-rmse:0.81353
# [733]#011train-rmse:0.54112#011validation-rmse:0.81381
# [734]#011train-rmse:0.54111#011validation-rmse:0.81413
# [735]#011train-rmse:0.54112#011validation-rmse:0.81368
# [736]#011train-rmse:0.54112#011validation-rmse:0.81367
# [737]#011train-rmse:0.54114#011validation-rmse:0.81323
# [738]#011train-rmse:0.54111#011validation-rmse:0.81396
# [739]#011train-rmse:0.54111#011validation-rmse:0.81390
# [740]#011train-rmse:0.54056#011validation-rmse:0.81230
# [741]#011train-rmse:0.54057#011validation-rmse:0.81323
# [742]#011train-rmse:0.54057#011validation-rmse:0.81310
# [743]#011train-rmse:0.54056#011validation-rmse:0.81243
# [744]#011train-rmse:0.54056#011validation-rmse:0.81271
# [745]#011train-rmse:0.54059#011validation-rmse:0.81365
# [746]#011train-rmse:0.54058#011validation-rmse:0.81342
# [747]#011train-rmse:0.54057#011validation-rmse:0.81222
# [748]#011train-rmse:0.54058#011validation-rmse:0.81174
# [749]#011train-rmse:0.54057#011validation-rmse:0.81220
# [750]#011train-rmse:0.54056#011validation-rmse:0.81243
# [751]#011train-rmse:0.54058#011validation-rmse:0.81177
# [752]#011train-rmse:0.54057#011validation-rmse:0.81216
# [753]#011train-rmse:0.54058#011validation-rmse:0.81185
# [754]#011train-rmse:0.54057#011validation-rmse:0.81204
# [755]#011train-rmse:0.54057#011validation-rmse:0.81227
# [756]#011train-rmse:0.54057#011validation-rmse:0.81205
# [757]#011train-rmse:0.54058#011validation-rmse:0.81193
# [758]#011train-rmse:0.53968#011validation-rmse:0.81023
# [810]#011train-rmse:0.53829#011validation-rmse:0.80881
# [811]#011train-rmse:0.53830#011validation-rmse:0.80944
# [812]#011train-rmse:0.53612#011validation-rmse:0.80824
# [813]#011train-rmse:0.53612#011validation-rmse:0.80797
# [814]#011train-rmse:0.53612#011validation-rmse:0.80782
# [815]#011train-rmse:0.53612#011validation-rmse:0.80831
# [816]#011train-rmse:0.53612#011validation-rmse:0.80833
# [817]#011train-rmse:0.53612#011validation-rmse:0.80755
# [818]#011train-rmse:0.53612#011validation-rmse:0.80808
# [819]#011train-rmse:0.53613#011validation-rmse:0.80862
# [820]#011train-rmse:0.53613#011validation-rmse:0.80863
# [821]#011train-rmse:0.53613#011validation-rmse:0.80837
# [822]#011train-rmse:0.53613#011validation-rmse:0.80858
# [823]#011train-rmse:0.53614#011validation-rmse:0.80880
# [824]#011train-rmse:0.53612#011validation-rmse:0.80760
# [825]#011train-rmse:0.53612#011validation-rmse:0.80760
# [826]#011train-rmse:0.53613#011validation-rmse:0.80745
# [827]#011train-rmse:0.53613#011validation-rmse:0.80728
# [828]#011train-rmse:0.53613#011validation-rmse:0.80739
# [829]#011train-rmse:0.53614#011validation-rmse:0.80703
# [830]#011train-rmse:0.53614#011validation-rmse:0.80719
# [831]#011train-rmse:0.53363#011validation-rmse:0.80540
# [832]#011train-rmse:0.53362#011validation-rmse:0.80550
# [833]#011train-rmse:0.53363#011validation-rmse:0.80541
# [834]#011train-rmse:0.53362#011validation-rmse:0.80558
# [835]#011train-rmse:0.53363#011validation-rmse:0.80634
# [836]#011train-rmse:0.53364#011validation-rmse:0.80647
# [837]#011train-rmse:0.53362#011validation-rmse:0.80587
# [838]#011train-rmse:0.53148#011validation-rmse:0.80943
# [839]#011train-rmse:0.53147#011validation-rmse:0.80899
# [840]#011train-rmse:0.53146#011validation-rmse:0.80895
# [841]#011train-rmse:0.53146#011validation-rmse:0.80868
# [842]#011train-rmse:0.53147#011validation-rmse:0.80814
# [843]#011train-rmse:0.53146#011validation-rmse:0.80843
# [844]#011train-rmse:0.53146#011validation-rmse:0.80890
# [845]#011train-rmse:0.53147#011validation-rmse:0.80901
# [846]#011train-rmse:0.53148#011validation-rmse:0.80783
# [847]#011train-rmse:0.53147#011validation-rmse:0.80817
# [848]#011train-rmse:0.53147#011validation-rmse:0.80828
# [849]#011train-rmse:0.53147#011validation-rmse:0.80805
# [850]#011train-rmse:0.53147#011validation-rmse:0.80817
# [851]#011train-rmse:0.53152#011validation-rmse:0.80722
# [852]#011train-rmse:0.53043#011validation-rmse:0.81167
# [853]#011train-rmse:0.53045#011validation-rmse:0.81109
# [854]#011train-rmse:0.53045#011validation-rmse:0.81107
# [855]#011train-rmse:0.53048#011validation-rmse:0.81052
# [856]#011train-rmse:0.53050#011validation-rmse:0.81030
# [857]#011train-rmse:0.53046#011validation-rmse:0.81084
# [858]#011train-rmse:0.53046#011validation-rmse:0.81083
# [859]#011train-rmse:0.53044#011validation-rmse:0.81111
# [860]#011train-rmse:0.53043#011validation-rmse:0.81184
# [861]#011train-rmse:0.53043#011validation-rmse:0.81173
# [862]#011train-rmse:0.53043#011validation-rmse:0.81208
# [863]#011train-rmse:0.53043#011validation-rmse:0.81229
# [864]#011train-rmse:0.53046#011validation-rmse:0.81303
# [865]#011train-rmse:0.53044#011validation-rmse:0.81248
# [866]#011train-rmse:0.53048#011validation-rmse:0.81321
# [867]#011train-rmse:0.53047#011validation-rmse:0.81314
# [868]#011train-rmse:0.53047#011validation-rmse:0.81317
# [869]#011train-rmse:0.53047#011validation-rmse:0.81307
# [870]#011train-rmse:0.53044#011validation-rmse:0.81242
# [871]#011train-rmse:0.53043#011validation-rmse:0.81148
# [872]#011train-rmse:0.53044#011validation-rmse:0.81121
# [873]#011train-rmse:0.53043#011validation-rmse:0.81156
# [874]#011train-rmse:0.53043#011validation-rmse:0.81197
# [875]#011train-rmse:0.53044#011validation-rmse:0.81238
# [876]#011train-rmse:0.53043#011validation-rmse:0.81174
# [877]#011train-rmse:0.53043#011validation-rmse:0.81154
# [878]#011train-rmse:0.53044#011validation-rmse:0.81113
# [879]#011train-rmse:0.53044#011validation-rmse:0.81131
# [880]#011train-rmse:0.53048#011validation-rmse:0.81049
# [881]#011train-rmse:0.53045#011validation-rmse:0.81108
# [882]#011train-rmse:0.53046#011validation-rmse:0.81086
# [883]#011train-rmse:0.53045#011validation-rmse:0.81092
# [884]#011train-rmse:0.53044#011validation-rmse:0.81130
# [885]#011train-rmse:0.53043#011validation-rmse:0.81139
# [886]#011train-rmse:0.53043#011validation-rmse:0.81195
# [887]#011train-rmse:0.53043#011validation-rmse:0.81166
# [888]#011train-rmse:0.53043#011validation-rmse:0.81213
# [889]#011train-rmse:0.53043#011validation-rmse:0.81223
# [890]#011train-rmse:0.53043#011validation-rmse:0.81151
# [891]#011train-rmse:0.53045#011validation-rmse:0.81269
# [892]#011train-rmse:0.53045#011validation-rmse:0.81281
# [893]#011train-rmse:0.53045#011validation-rmse:0.81265
# [894]#011train-rmse:0.53047#011validation-rmse:0.81315
# [895]#011train-rmse:0.53043#011validation-rmse:0.81198
# [896]#011train-rmse:0.53043#011validation-rmse:0.81160
# [897]#011train-rmse:0.53043#011validation-rmse:0.81177
# [898]#011train-rmse:0.53044#011validation-rmse:0.81118
# [899]#011train-rmse:0.53043#011validation-rmse:0.81178
# [900]#011train-rmse:0.53044#011validation-rmse:0.81120
# [901]#011train-rmse:0.53043#011validation-rmse:0.81164
# [902]#011train-rmse:0.52873#011validation-rmse:0.81514
# [903]#011train-rmse:0.52873#011validation-rmse:0.81487
# [904]#011train-rmse:0.52874#011validation-rmse:0.81446
# [905]#011train-rmse:0.52873#011validation-rmse:0.81469
# [906]#011train-rmse:0.52875#011validation-rmse:0.81425
# [907]#011train-rmse:0.52874#011validation-rmse:0.81441
# [908]#011train-rmse:0.52875#011validation-rmse:0.81423
# [909]#011train-rmse:0.52875#011validation-rmse:0.81419
# [910]#011train-rmse:0.52873#011validation-rmse:0.81471
# [911]#011train-rmse:0.52873#011validation-rmse:0.81501
# [912]#011train-rmse:0.52873#011validation-rmse:0.81493
# [913]#011train-rmse:0.52873#011validation-rmse:0.81553
# [914]#011train-rmse:0.52873#011validation-rmse:0.81561
# [915]#011train-rmse:0.52874#011validation-rmse:0.81592
# [916]#011train-rmse:0.52873#011validation-rmse:0.81510
# [917]#011train-rmse:0.52873#011validation-rmse:0.81515
# [918]#011train-rmse:0.52874#011validation-rmse:0.81456
# [919]#011train-rmse:0.52877#011validation-rmse:0.81401
# [920]#011train-rmse:0.52877#011validation-rmse:0.81395
# [921]#011train-rmse:0.52877#011validation-rmse:0.81392
# [922]#011train-rmse:0.52873#011validation-rmse:0.81484
# [923]#011train-rmse:0.52874#011validation-rmse:0.81439
# [924]#011train-rmse:0.52873#011validation-rmse:0.81531
# [925]#011train-rmse:0.52873#011validation-rmse:0.81577
# [926]#011train-rmse:0.52873#011validation-rmse:0.81514
# [927]#011train-rmse:0.52834#011validation-rmse:0.81749
# [928]#011train-rmse:0.52834#011validation-rmse:0.81754
# [929]#011train-rmse:0.52835#011validation-rmse:0.81723
# [930]#011train-rmse:0.52834#011validation-rmse:0.81738
# [931]#011train-rmse:0.52835#011validation-rmse:0.81706
# [932]#011train-rmse:0.52834#011validation-rmse:0.81772
# [933]#011train-rmse:0.52834#011validation-rmse:0.81752
# [934]#011train-rmse:0.52836#011validation-rmse:0.81693
# [935]#011train-rmse:0.52835#011validation-rmse:0.81729
# [936]#011train-rmse:0.52834#011validation-rmse:0.81742
# [937]#011train-rmse:0.52834#011validation-rmse:0.81741
# [938]#011train-rmse:0.52836#011validation-rmse:0.81703
# [939]#011train-rmse:0.52835#011validation-rmse:0.81725
# [940]#011train-rmse:0.52835#011validation-rmse:0.81718
# [941]#011train-rmse:0.52835#011validation-rmse:0.81715
# [942]#011train-rmse:0.52841#011validation-rmse:0.81618
# [943]#011train-rmse:0.52838#011validation-rmse:0.81655
# [944]#011train-rmse:0.52835#011validation-rmse:0.81716
# [945]#011train-rmse:0.52835#011validation-rmse:0.81727
# [946]#011train-rmse:0.52838#011validation-rmse:0.81649
# [947]#011train-rmse:0.52835#011validation-rmse:0.81706
# [948]#011train-rmse:0.52835#011validation-rmse:0.81730
# [949]#011train-rmse:0.52835#011validation-rmse:0.81732
# [950]#011train-rmse:0.52834#011validation-rmse:0.81782
# [951]#011train-rmse:0.52835#011validation-rmse:0.81838
# [952]#011train-rmse:0.52835#011validation-rmse:0.81820
# [953]#011train-rmse:0.52835#011validation-rmse:0.81710
# [954]#011train-rmse:0.52836#011validation-rmse:0.81689
# [955]#011train-rmse:0.52837#011validation-rmse:0.81667
# [956]#011train-rmse:0.52838#011validation-rmse:0.81657
# [957]#011train-rmse:0.52836#011validation-rmse:0.81690
# [958]#011train-rmse:0.52838#011validation-rmse:0.81652
# [959]#011train-rmse:0.52835#011validation-rmse:0.81716
# [960]#011train-rmse:0.52837#011validation-rmse:0.81668
# [961]#011train-rmse:0.52837#011validation-rmse:0.81667
# [962]#011train-rmse:0.52835#011validation-rmse:0.81727
# [963]#011train-rmse:0.52834#011validation-rmse:0.81785
# [964]#011train-rmse:0.52834#011validation-rmse:0.81762
# [965]#011train-rmse:0.52835#011validation-rmse:0.81712
# [966]#011train-rmse:0.52836#011validation-rmse:0.81682
# [967]#011train-rmse:0.52835#011validation-rmse:0.81729
# [968]#011train-rmse:0.52834#011validation-rmse:0.81789
# [969]#011train-rmse:0.52835#011validation-rmse:0.81818
# [970]#011train-rmse:0.52834#011validation-rmse:0.81789
# [971]#011train-rmse:0.52836#011validation-rmse:0.81686
# [972]#011train-rmse:0.52836#011validation-rmse:0.81680
# [973]#011train-rmse:0.52835#011validation-rmse:0.81735
# [974]#011train-rmse:0.52834#011validation-rmse:0.81767
# [975]#011train-rmse:0.52834#011validation-rmse:0.81742
# [976]#011train-rmse:0.52835#011validation-rmse:0.81727
# [977]#011train-rmse:0.52837#011validation-rmse:0.81675
# [978]#011train-rmse:0.52838#011validation-rmse:0.81648
# [979]#011train-rmse:0.52834#011validation-rmse:0.81745
# [980]#011train-rmse:0.52834#011validation-rmse:0.81771
# [981]#011train-rmse:0.52836#011validation-rmse:0.81693
# [982]#011train-rmse:0.52835#011validation-rmse:0.81724
# [983]#011train-rmse:0.52836#011validation-rmse:0.81703
# [984]#011train-rmse:0.52835#011validation-rmse:0.81832
# [985]#011train-rmse:0.52835#011validation-rmse:0.81830
# [986]#011train-rmse:0.52836#011validation-rmse:0.81848
# [987]#011train-rmse:0.52836#011validation-rmse:0.81847
# [988]#011train-rmse:0.52835#011validation-rmse:0.81830
# [989]#011train-rmse:0.52836#011validation-rmse:0.81856
# [990]#011train-rmse:0.52835#011validation-rmse:0.81839
# [991]#011train-rmse:0.52835#011validation-rmse:0.81830
# [992]#011train-rmse:0.52834#011validation-rmse:0.81783
# [993]#011train-rmse:0.52834#011validation-rmse:0.81769
# [994]#011train-rmse:0.52834#011validation-rmse:0.81778
# [995]#011train-rmse:0.52834#011validation-rmse:0.81776
# [996]#011train-rmse:0.52834#011validation-rmse:0.81794
# [997]#011train-rmse:0.52834#011validation-rmse:0.81804
# [998]#011train-rmse:0.52835#011validation-rmse:0.81724
# [999]#011train-rmse:0.52838#011validation-rmse:0.81656
#
# 2023-01-16 08:58:28 Uploading - Uploading generated training model
# 2023-01-16 08:58:28 Completed - Training job completed
# Training seconds: 117
# Billable seconds: 117

# %%
from sagemaker.serializers import CSVSerializer

xgb_predictor = estimator.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge', serializer = CSVSerializer())
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2023-01-16-08-58-57-469
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2023-01-16-08-58-57-469
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2023-01-16-08-58-57-469
# ------!

# %%
predictions = xgb_predictor.predict(X_test.values).decode('utf-8')
y_preds = np.fromstring(predictions, sep='\n')
y_preds
# Out:
# array([6.33967447, 5.27834129, 5.18182802, 6.52271795, 5.01564455,
#        5.1010828 , 5.23800802, 8.37554455, 5.70354843, 6.19517756,
#        6.06058931, 7.43921471, 6.4201684 , 5.70805073, 6.66614866,
#        7.8162818 , 5.37521219, 6.92956352, 7.28550482, 5.4831295 ,
#        4.0953784 , 5.73403549, 5.85450459, 8.0687685 , 5.8023324 ,
#        8.26784992, 6.015625  , 6.52586555, 9.34286213, 6.66070986,
#        5.30417109, 7.28687286, 6.87459898, 5.99541044, 5.80041361,
#        7.06702471, 6.39491415, 6.57245445, 6.37933683, 6.51789236,
#        7.94397163, 6.39472961, 5.91348982, 6.61259937, 6.5731988 ,
#        6.28219032, 6.4868145 , 5.14106464, 6.37257051, 6.05520964,
#        6.91374683, 5.93503237, 5.78766584, 6.79505634, 5.90298653,
#        5.34210873, 5.93279743, 3.59774017, 5.36846447, 6.668643  ,
#        6.33507395, 3.87094259, 6.41080904, 5.73552847, 4.62413931,
#        1.98669922, 5.10040283, 5.49983215, 3.29827929, 6.13534451,
#        6.08099556, 6.35636377, 6.52167892, 6.79176712, 6.25344229,
#        6.58283329, 6.81787968, 6.38014364, 6.12727499, 5.69813299,
#        5.30405235, 5.30692005, 5.05083227, 5.2159214 , 5.68845081,
#        5.46514845, 6.44660521, 6.33967447, 5.06834078, 5.56037521,
#        6.05520964, 6.73674202, 6.62962866, 5.6254487 , 7.8365283 ,
#        8.27604866, 4.95238686, 6.54969788, 6.58232641, 6.58506918,
#        7.84183979, 5.4709444 , 5.51690483, 6.54413176, 5.83593178,
#        6.17615175, 4.74214411, 5.84310341, 5.11387396, 6.48553038,
#        5.87948656, 5.83448124, 4.14022541, 6.50830746, 4.4290514 ,
#        6.25546026, 6.14942837, 6.01977539, 6.35260773, 6.06058931,
#        6.09530592, 6.46590662, 5.80041361, 6.92928648, 6.17339325,
#        6.46590662, 6.68694115, 7.06797981, 6.53312588, 6.30694675,
#        6.34241104, 5.14837885, 4.77790022, 6.66652679, 7.2659359 ,
#        5.47401571, 9.30737114, 7.00314856, 6.75729227, 4.8518014 ,
#        5.43306732, 4.77486372, 6.50590754, 5.62179995, 6.03669357,
#        6.09809589, 5.57884693, 4.91363764, 6.92540407, 6.43810987,
#        5.82605314, 9.90073776, 6.41984129, 5.45924187, 6.26911592,
#        5.05389929, 5.60532093, 4.59585762, 8.02228832, 6.14560509,
#        5.97469473, 6.7166791 , 6.89078474, 5.50769138, 6.68112803,
#        6.02276945, 5.18355417, 6.19634819, 6.09488153, 6.86433268,
#        6.02983427, 6.0791707 , 6.64375782, 7.07609653, 5.97192144,
#        7.00781536, 6.33840847, 6.06242085, 7.03454685, 6.49208117,
#        6.44510508, 6.42818642, 5.96093321, 5.92223549, 5.8523469 ,
#        6.61596155, 6.48638964, 6.10112476, 6.55362368, 6.77038527,
#        6.33683825, 6.92417622, 6.18589735, 5.98666811])

# %%
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_test, y_preds, squared=False)
frac = rmse/y_test.mean()
frac
# Out:
# 0.12963276462442194

# %%
rmse
# Out:
# 0.81655675956416

# %%
# Utility Code

# %%
# Assert that training file is in the bucket

# !aws s3 ls finkers-bucket/train --recursive
# Out:
# 2023-01-16 07:43:51          0 training/
# 2023-01-16 07:44:45     137338 training/final_training.csv

# %%
# Run to delete endpoint only
sgemaker_boto3.delete_endpoint(EndpointName=xgb_predictor.endpoint)
